# %%
from google.cloud import aiplatform

import tensorflow as tf
import numpy as np
import asyncio
import aiohttp
import json
import glob
import time
from PIL import Image
from statistics import mean
from io import BytesIO

# %%
# Setup endpoint

# CHANGE THESE
PROJECT_NUMBER = "827354046383"
ENDPOINT_ID = "4703099415160684544" #1node8core7.5gb
auth_token = "ya29.c.b0AUFJQsGD4I7d2uhUy6E4sd_XAQJuD5RDxOjUW59iRnh3TDMyNrITtlHJ7wOdDZVYRWAPTnCK7xQ18ITsmRu5B75461J5BOIU7vtwSh2eQ3PFqJg0QDTHSVnfnakj3w0tenN4Gx7lf7ymruGmYtut5zmHX0y5g4QKL5I-KJ4FI4TwM5sIUcJkcJiZiniex7E7UxlDQuoc4tr6hjnKRP78F62aV9mFP62ueURgiNUf"

endpoint = aiplatform.Endpoint(
    endpoint_name=f"projects/{PROJECT_NUMBER}/locations/us-central1/endpoints/{ENDPOINT_ID}")

url="https://us-central1-aiplatform.googleapis.com/v1beta1/projects/{}/locations/us-central1/endpoints/{}:predict".format(PROJECT_NUMBER, ENDPOINT_ID)

# Download image labels
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())

# %%
# Image prep, Set number of jobs in a batch

file = 'imagenet/*.jpg'
file_string = glob.glob(file)
IMAGE_SIZE = (200, 200)
instances = []
njobs = 10 # number of jobs per batch
offset = 100

for x in range(njobs):
    # print(file_string[x+offset])
    im = Image.open(file_string[x+offset])
    im = im.resize(IMAGE_SIZE)
    im = np.array(im)/255.0
    img_str = im.astype(np.float32).tolist()
    instances.append(img_str)

# %%
nbatches = 5 # number of batches

# Batch response times
batch_response_times = []
batch_response_times = [0 for i in range(nbatches)]

# interarrival times for batches
inter_arrival_times = []
inter_arrival_times = [3 for i in range(nbatches)]
inter_arrival_times[0] = 0

# arrival times of batches
arrival_times = []
arrival_times = [0 for i in range(nbatches)]
arrival_times[0]=round(inter_arrival_times[0],2)#arrival of first customer
#Generate arrival times
for i in range(1,nbatches):
    arrival_times[i]=round((arrival_times[i-1]+inter_arrival_times[i]),2)
    
print("Batch interarrival times {}".format(inter_arrival_times))
print("Batch arrival times      {}".format(arrival_times))
# Out:
# Batch interarrival times [0, 3, 3, 3, 3]
# Batch arrival times      [0, 3, 6, 9, 12]

# %%
# Single prediction request
@asyncio.coroutine
async def predict_single(session: aiohttp.ClientSession, instances: list, curCust: int, offset: int, start_time: float) -> dict:
    job_sent_time = time.monotonic()
    headers = {"Authorization": "Bearer {}".format(auth_token)}
    payload = {"instances" : instances[curCust:(curCust+1)]}
    resp = await session.post(url, json=payload, headers=headers) 
    data = await resp.json()
    return data

# Batch prediction request
@asyncio.coroutine
async def predict_batch(session, instances, b, offset, start_time):
    # Simulating arrival times
    await asyncio.sleep(arrival_times[b])
    print("Starting batch {} at {}s after start".format(b, time.monotonic() - start_time))
    batch_start_time = time.monotonic()
    tasks = []
    for c in range(0,njobs):
        tasks.append(predict_single(session=session, instances=instances, curCust=c, offset=offset, start_time=start_time))
    jobs = await asyncio.gather(*tasks, return_exceptions=True)
    batch_finish_time = time.monotonic() - batch_start_time
    batch_response_times[b] = batch_finish_time
    print("Batch {} complete after {}s".format(b,batch_finish_time))
    
    return jobs

async def main(instances):
    async with aiohttp.ClientSession() as session:
        start_time = time.monotonic()
        batch_tasks = []
        for b in range(0,nbatches):
            batch_tasks.append(predict_batch(session, instances, b, offset, start_time))
        batches = await asyncio.gather(*batch_tasks, return_exceptions=True)
        total_time = time.monotonic() - start_time
        print("{} batches of {} jobs each took {}s".format(nbatches, njobs, total_time))
        print("Response times {}".format(batch_response_times))
        print("Mean batch response time {}".format(mean(batch_response_times)))

        return batches

await main(instances)
# Out:
# Initiating batch 0 coroutine at 3.6460000956139993e-06s after start
# Initiating batch 1 coroutine at 0.00010630299993863446s after start
# Initiating batch 2 coroutine at 0.0001255259999197733s after start
# Initiating batch 3 coroutine at 0.00014236700008041225s after start
# Initiating batch 4 coroutine at 0.00015557699998680619s after start
# Initiating batch 5 coroutine at 0.00016791899997770088s after start
# Initiating batch 6 coroutine at 0.00018009499990512268s after start
# Initiating batch 7 coroutine at 0.00019236300022384967s after start
# Initiating batch 8 coroutine at 0.00020460599989746697s after start
# Initiating batch 9 coroutine at 0.00021667800001523574s after start
# Initiating batch 10 coroutine at 0.00022850999994261656s after start
# Initiating batch 11 coroutine at 0.00024039500021899585s after start
# Initiating batch 12 coroutine at 0.0002544769999985874s after start
# Initiating batch 13 coroutine at 0.0002673270000741468s after start
# Initiating batch 14 coroutine at 0.00028046199986420106s after start
# Initiating batch 15 coroutine at 0.00029223399997135857s after start
# Initiating batch 16 coroutine at 0.00035512200020093587s after start
# Initiating batch 17 coroutine at 0.00036768500012840377s after start
# Initiating batch 18 coroutine at 0.0003804550001405005s after start
# Initiating batch 19 coroutine at 0.00039216100003613974s after start
# Initiating batch 20 coroutine at 0.00040455399994243635s after start
# Initiating batch 21 coroutine at 0.00042306100021960447s after start
# Initiating batch 22 coroutine at 0.00043523700014702627s after start
# Initiating batch 23 coroutine at 0.0004470510002647643s after start
# Initiating batch 24 coroutine at 0.0004602300000442483s after start
# Initiating batch 25 coroutine at 0.0004720100000668026s after start
# Initiating batch 26 coroutine at 0.0004840229998990253s after start
# Initiating batch 27 coroutine at 0.0005011349999222148s after start
# Initiating batch 28 coroutine at 0.0005206989999351208s after start
# Initiating batch 29 coroutine at 0.0005368810002437385s after start
# Initiating batch 30 coroutine at 0.0005518830002984032s after start
# Initiating batch 31 coroutine at 0.0005671650001204398s after start
# Initiating batch 32 coroutine at 0.0006163400003060815s after start
# Initiating batch 33 coroutine at 0.000629008000032627s after start
# Initiating batch 34 coroutine at 0.0006413500000235217s after start
# Initiating batch 35 coroutine at 0.0006537190001836279s after start
# Initiating batch 36 coroutine at 0.0006663980002485914s after start
# Initiating batch 37 coroutine at 0.0006789899998693727s after start
# Initiating batch 38 coroutine at 0.000690860000304383s after start
# Initiating batch 39 coroutine at 0.0007030860001577821s after start
# Initiating batch 40 coroutine at 0.0007149860002755304s after start
# Initiating batch 41 coroutine at 0.000726816000224062s after start
# Initiating batch 42 coroutine at 0.0007386679999399348s after start
# Initiating batch 43 coroutine at 0.0007502950002162834s after start
# Initiating batch 44 coroutine at 0.0007622200000696466s after start
# Initiating batch 45 coroutine at 0.0007745480002085969s after start
# Initiating batch 46 coroutine at 0.0007865110001148423s after start
# Initiating batch 47 coroutine at 0.0007982830002219998s after start
# Initiating batch 48 coroutine at 0.0008107419998850673s after start
# Initiating batch 49 coroutine at 0.0008226230002037482s after start
# Initiating batch 50 coroutine at 0.0008343919998878846s after start
# Initiating batch 51 coroutine at 0.0008463869999104645s after start
# Initiating batch 52 coroutine at 0.0008582919999753358s after start
# Initiating batch 53 coroutine at 0.0008700970001882524s after start
# Initiating batch 54 coroutine at 0.0008826900002532057s after start
# Initiating batch 55 coroutine at 0.000894886999958544s after start
# Initiating batch 56 coroutine at 0.0009070060000340163s after start
# Initiating batch 57 coroutine at 0.0009194670001306804s after start
# Initiating batch 58 coroutine at 0.0009312440001849609s after start
# Initiating batch 59 coroutine at 0.0009431480002604076s after start
# Initiating batch 60 coroutine at 0.0009548739999445388s after start
# Initiating batch 61 coroutine at 0.0009665420002420433s after start
# Initiating batch 62 coroutine at 0.000978634000148304s after start
# Initiating batch 63 coroutine at 0.0009906989998853533s after start
# Initiating batch 64 coroutine at 0.0010044880000350531s after start
# Initiating batch 65 coroutine at 0.0010163169999941601s after start
# Initiating batch 66 coroutine at 0.001028157000291685s after start
# Initiating batch 67 coroutine at 0.0010403820001556596s after start
# Initiating batch 68 coroutine at 0.0010526169999138801s after start
# Initiating batch 69 coroutine at 0.0010644750000210479s after start
# Initiating batch 70 coroutine at 0.00107621699999072s after start
# Initiating batch 71 coroutine at 0.001088034000076732s after start
# Initiating batch 72 coroutine at 0.001099942000109877s after start
# Initiating batch 73 coroutine at 0.0011127000002488785s after start
# Initiating batch 74 coroutine at 0.0011245680002502922s after start
# Initiating batch 75 coroutine at 0.0011394269999982498s after start
# Initiating batch 76 coroutine at 0.0011522370000420779s after start
# Initiating batch 77 coroutine at 0.0011638770001809462s after start
# Initiating batch 78 coroutine at 0.0013295700000526267s after start
# Initiating batch 79 coroutine at 0.0013429609998638625s after start
# Initiating batch 80 coroutine at 0.0013551880001614336s after start
# Initiating batch 81 coroutine at 0.0013674410001840442s after start
# Initiating batch 82 coroutine at 0.0013798680001855246s after start
# Initiating batch 83 coroutine at 0.0013920619999225892s after start
# Initiating batch 84 coroutine at 0.0014041310000720841s after start
# Initiating batch 85 coroutine at 0.0014163999999254884s after start
# Initiating batch 86 coroutine at 0.0014308300001175667s after start
# Initiating batch 87 coroutine at 0.001443699999981618s after start
# Initiating batch 88 coroutine at 0.0014557909998984542s after start
# Initiating batch 89 coroutine at 0.0014679870000691153s after start
# Initiating batch 90 coroutine at 0.0014799509999647853s after start
# Initiating batch 91 coroutine at 0.0014921770002729318s after start
# Initiating batch 92 coroutine at 0.0015041179999570886s after start
# Initiating batch 93 coroutine at 0.001516020000053686s after start
# Initiating batch 94 coroutine at 0.0015282399999705376s after start
# Initiating batch 95 coroutine at 0.0015404460000354447s after start
# Initiating batch 96 coroutine at 0.0015523840002060751s after start
# Initiating batch 97 coroutine at 0.0015641770000911492s after start
# Initiating batch 98 coroutine at 0.0015759749999233463s after start
# Initiating batch 99 coroutine at 0.0015892290002739173s after start
# Initiating batch 100 coroutine at 0.0016012310002224694s after start
# Initiating batch 101 coroutine at 0.0016140170000653598s after start
# Initiating batch 102 coroutine at 0.0016260810002677317s after start
# Initiating batch 103 coroutine at 0.001638054000068223s after start
# Initiating batch 104 coroutine at 0.001650003000122524s after start
# Initiating batch 105 coroutine at 0.0016620380001768353s after start
# Initiating batch 106 coroutine at 0.0016739500001676788s after start
# Initiating batch 107 coroutine at 0.0016867970002749644s after start
# Initiating batch 108 coroutine at 0.001698949999990873s after start
# Initiating batch 109 coroutine at 0.0017109410000557546s after start
# Initiating batch 110 coroutine at 0.001722978000088915s after start
# Initiating batch 111 coroutine at 0.001734857999963424s after start
# Initiating batch 112 coroutine at 0.0017469670001446502s after start
# Initiating batch 113 coroutine at 0.0017594939999980852s after start
# Initiating batch 114 coroutine at 0.0017720060000101512s after start
# Initiating batch 115 coroutine at 0.00178394800013848s after start
# Initiating batch 116 coroutine at 0.0017955660000552598s after start
# Initiating batch 117 coroutine at 0.0018081880002682738s after start
# Initiating batch 118 coroutine at 0.001820233000216831s after start
# Initiating batch 119 coroutine at 0.0018320280000807543s after start
# Initiating batch 120 coroutine at 0.001843901000029291s after start
# Initiating batch 121 coroutine at 0.0018562620002740005s after start
# Initiating batch 122 coroutine at 0.001868287999968743s after start
# Initiating batch 123 coroutine at 0.001880111999980727s after start
# Initiating batch 124 coroutine at 0.0018922570002359862s after start
# Initiating batch 125 coroutine at 0.001904173000184528s after start
# Initiating batch 126 coroutine at 0.0019161280001753767s after start
# Initiating batch 127 coroutine at 0.0019283080000604969s after start
# Initiating batch 128 coroutine at 0.0019401680001465138s after start
# Initiating batch 129 coroutine at 0.0019522319998941384s after start
# Initiating batch 130 coroutine at 0.0019642880001811136s after start
# Initiating batch 131 coroutine at 0.001976646000002802s after start
# Initiating batch 132 coroutine at 0.0019889850000254228s after start
# Initiating batch 133 coroutine at 0.0020012630002383958s after start
# Initiating batch 134 coroutine at 0.0020131629999013967s after start
# Initiating batch 135 coroutine at 0.0020252929998605396s after start
# Initiating batch 136 coroutine at 0.0020370340002955345s after start
# Initiating batch 137 coroutine at 0.002049059999990277s after start
# Initiating batch 138 coroutine at 0.0020607559999916703s after start
# Initiating batch 139 coroutine at 0.0020726080001622904s after start
# Initiating batch 140 coroutine at 0.002084291000301164s after start
# Initiating batch 141 coroutine at 0.002096079000239115s after start
# Initiating batch 142 coroutine at 0.0021077490000607213s after start
# Initiating batch 143 coroutine at 0.002119730000231357s after start
# Initiating batch 144 coroutine at 0.0021313580000423826s after start
# Initiating batch 145 coroutine at 0.0021432900002764654s after start
# Initiating batch 146 coroutine at 0.0021549020002566976s after start
# Initiating batch 147 coroutine at 0.0021667940000043018s after start
# Initiating batch 148 coroutine at 0.0021786420002172235s after start
# Initiating batch 149 coroutine at 0.002190901000176382s after start
# Initiating batch 150 coroutine at 0.0022027380000508856s after start
# Initiating batch 151 coroutine at 0.0022144949998619268s after start
# Initiating batch 152 coroutine at 0.0022261580002123083s after start
# Initiating batch 153 coroutine at 0.0022382340002877754s after start
# Initiating batch 154 coroutine at 0.0022500439999930677s after start
# Initiating batch 155 coroutine at 0.0022631219999311725s after start
# Initiating batch 156 coroutine at 0.0022754770002393343s after start
# Initiating batch 157 coroutine at 0.002287582000008115s after start
# Initiating batch 158 coroutine at 0.0023046760002216615s after start
# Initiating batch 159 coroutine at 0.0023167570002442517s after start
# Initiating batch 160 coroutine at 0.002328809000118781s after start
# Initiating batch 161 coroutine at 0.002340573000310542s after start
# Initiating batch 162 coroutine at 0.0023521289999735018s after start
# Initiating batch 163 coroutine at 0.0023644779998903687s after start
# Initiating batch 164 coroutine at 0.0023762680002619163s after start
# Initiating batch 165 coroutine at 0.002388055000210443s after start
# Initiating batch 166 coroutine at 0.002399588000116637s after start
# Initiating batch 167 coroutine at 0.002411246000065148s after start
# Initiating batch 168 coroutine at 0.0024231699999290868s after start
# Initiating batch 169 coroutine at 0.002435048000279494s after start
# Initiating batch 170 coroutine at 0.002446624000185693s after start
# Initiating batch 171 coroutine at 0.002458288000070752s after start
# Initiating batch 172 coroutine at 0.00246994100007214s after start
# Initiating batch 173 coroutine at 0.0024814560001686914s after start
# Initiating batch 174 coroutine at 0.0024932659998739837s after start
# Initiating batch 175 coroutine at 0.0025049529999705555s after start
# Initiating batch 176 coroutine at 0.002516652999929647s after start
# Initiating batch 177 coroutine at 0.0025281829998675676s after start
# Initiating batch 178 coroutine at 0.0025408149999748275s after start
# Initiating batch 179 coroutine at 0.0025525230003040633s after start
# Initiating batch 180 coroutine at 0.0025643869998930313s after start
# Initiating batch 181 coroutine at 0.002575978000095347s after start
# Initiating batch 182 coroutine at 0.002587723000033293s after start
# Initiating batch 183 coroutine at 0.002621968000312336s after start
# Initiating batch 184 coroutine at 0.0026393440002721036s after start
# Initiating batch 185 coroutine at 0.002653743999871949s after start
# Initiating batch 186 coroutine at 0.0029663640002581815s after start
# Initiating batch 187 coroutine at 0.002985889000228781s after start
# Initiating batch 188 coroutine at 0.0029992519998813805s after start
# Initiating batch 189 coroutine at 0.003011216000231798s after start
# Initiating batch 190 coroutine at 0.0030231760001697694s after start
# Initiating batch 191 coroutine at 0.0030351119999068032s after start
# Initiating batch 192 coroutine at 0.0030468850000033854s after start
# Initiating batch 193 coroutine at 0.0030591059999096615s after start
# Initiating batch 194 coroutine at 0.0030710549999639625s after start
# Initiating batch 195 coroutine at 0.003083700999923167s after start
# Initiating batch 196 coroutine at 0.0030958470001678506s after start
# Initiating batch 197 coroutine at 0.0031135930003074463s after start
# Initiating batch 198 coroutine at 0.003133614000034868s after start
# Initiating batch 199 coroutine at 0.003149615999973321s after start
# Initiating batch 200 coroutine at 0.003164900000228954s after start
# Initiating batch 201 coroutine at 0.0031804850000298757s after start
# Initiating batch 202 coroutine at 0.0031979610002963454s after start
# Initiating batch 203 coroutine at 0.00565311800028212s after start
# Initiating batch 204 coroutine at 0.005689782999979798s after start
# Initiating batch 205 coroutine at 0.0057080560000031255s after start
# Initiating batch 206 coroutine at 0.0057268579998890345s after start
# Initiating batch 207 coroutine at 0.005745068000123865s after start
# Initiating batch 208 coroutine at 0.005762087000221072s after start
# Initiating batch 209 coroutine at 0.005778895000275952s after start
# Initiating batch 210 coroutine at 0.005806617999951413s after start
# Initiating batch 211 coroutine at 0.005823677000080352s after start
# Initiating batch 212 coroutine at 0.005840265000188083s after start
# Initiating batch 213 coroutine at 0.005856377999862161s after start
# Initiating batch 214 coroutine at 0.005873520000022836s after start
# Initiating batch 215 coroutine at 0.005889561000003596s after start
# Initiating batch 216 coroutine at 0.005905091999920842s after start
# Initiating batch 217 coroutine at 0.005921449000197754s after start
# Initiating batch 218 coroutine at 0.005937373000051593s after start
# Initiating batch 219 coroutine at 0.00595405900003243s after start
# Initiating batch 220 coroutine at 0.005971013999896968s after start
# Initiating batch 221 coroutine at 0.005988138000248s after start
# Initiating batch 222 coroutine at 0.006004792000112502s after start
# Initiating batch 223 coroutine at 0.0060212890002731s after start
# Initiating batch 224 coroutine at 0.006037652000031812s after start
# Initiating batch 225 coroutine at 0.006053819000044314s after start
# Initiating batch 226 coroutine at 0.006070001999887609s after start
# Initiating batch 227 coroutine at 0.006086562000291451s after start
# Initiating batch 228 coroutine at 0.0061031079999338544s after start
# Initiating batch 229 coroutine at 0.006119942000168521s after start
# Initiating batch 230 coroutine at 0.006136346999937814s after start
# Initiating batch 231 coroutine at 0.006152999000278214s after start
# Initiating batch 232 coroutine at 0.006171429999994871s after start
# Initiating batch 233 coroutine at 0.00620987199999945s after start
# Initiating batch 234 coroutine at 0.006228277999980492s after start
# Initiating batch 235 coroutine at 0.00624440899991896s after start
# Initiating batch 236 coroutine at 0.006260107999878528s after start
# Initiating batch 237 coroutine at 0.00627676900012375s after start
# Initiating batch 238 coroutine at 0.006293554999956541s after start
# Initiating batch 239 coroutine at 0.006310555000254681s after start
# Initiating batch 240 coroutine at 0.006327444999897125s after start
# Initiating batch 241 coroutine at 0.006344115000047168s after start
# Initiating batch 242 coroutine at 0.006360287999996217s after start
# Initiating batch 243 coroutine at 0.006376633999934711s after start
# Initiating batch 244 coroutine at 0.006393165000190493s after start
# Initiating batch 245 coroutine at 0.006409682000139583s after start
# Initiating batch 246 coroutine at 0.006426004999866564s after start
# Initiating batch 247 coroutine at 0.006442107000111719s after start
# Initiating batch 248 coroutine at 0.0064583409998704155s after start
# Initiating batch 249 coroutine at 0.006475070000306005s after start
# Initiating batch 250 coroutine at 0.006491884000297432s after start
# Initiating batch 251 coroutine at 0.0065083280001090316s after start
# Initiating batch 252 coroutine at 0.00652455799991003s after start
# Initiating batch 253 coroutine at 0.00654135300010239s after start
# Initiating batch 254 coroutine at 0.006557237999913923s after start
# Initiating batch 255 coroutine at 0.006573267000021588s after start
# Initiating batch 256 coroutine at 0.006588852000277257s after start
# Initiating batch 257 coroutine at 0.006634212999870215s after start
# Initiating batch 258 coroutine at 0.006651566000073217s after start
# Initiating batch 259 coroutine at 0.0066676199999164965s after start
# Initiating batch 260 coroutine at 0.006683880000309728s after start
# Initiating batch 261 coroutine at 0.006699506000131805s after start
# Initiating batch 262 coroutine at 0.006715266999890446s after start
# Initiating batch 263 coroutine at 0.006730285000230651s after start
# Initiating batch 264 coroutine at 0.0067481240002962295s after start
# Initiating batch 265 coroutine at 0.006764203999864549s after start
# Initiating batch 266 coroutine at 0.0067807880000145815s after start
# Initiating batch 267 coroutine at 0.006805445000281907s after start
# Initiating batch 268 coroutine at 0.0068217349999031285s after start
# Initiating batch 269 coroutine at 0.006838349000190647s after start
# Initiating batch 270 coroutine at 0.0068556530000023486s after start
# Initiating batch 271 coroutine at 0.006871585000226332s after start
# Initiating batch 272 coroutine at 0.00688802200011196s after start
# Initiating batch 273 coroutine at 0.006903217999933986s after start
# Initiating batch 274 coroutine at 0.006919285000094533s after start
# Initiating batch 275 coroutine at 0.00693536300013875s after start
# Initiating batch 276 coroutine at 0.006951200000003155s after start
# Initiating batch 277 coroutine at 0.006968055000015738s after start
# Initiating batch 278 coroutine at 0.006983878000028199s after start
# Initiating batch 279 coroutine at 0.006999065999934828s after start
# Initiating batch 280 coroutine at 0.007014395000169316s after start
# Initiating batch 281 coroutine at 0.007029640999917319s after start
# Initiating batch 282 coroutine at 0.007044966000194108s after start
# Initiating batch 283 coroutine at 0.007060204000026715s after start
# Initiating batch 284 coroutine at 0.007073539999964851s after start
# Initiating batch 285 coroutine at 0.007085301000188338s after start
# Initiating batch 286 coroutine at 0.007097197999883065s after start
# Initiating batch 287 coroutine at 0.007108856000286323s after start
# Initiating batch 288 coroutine at 0.00712056800011851s after start
# Initiating batch 289 coroutine at 0.007132237999940116s after start
# Initiating batch 290 coroutine at 0.0071439960001953295s after start
# Initiating batch 291 coroutine at 0.007155826000143861s after start
# Initiating batch 292 coroutine at 0.007168094000007841s after start
# Initiating batch 293 coroutine at 0.00718072800009395s after start
# Initiating batch 294 coroutine at 0.0071924640001270745s after start
# Initiating batch 295 coroutine at 0.007204536000244843s after start
# Initiating batch 296 coroutine at 0.0072162520000347286s after start
# Initiating batch 297 coroutine at 0.007230692000121053s after start
# Initiating batch 298 coroutine at 0.007246421000218106s after start
# Initiating batch 299 coroutine at 0.0072618770000190125s after start
# Initiating batch 300 coroutine at 0.0072772580001583265s after start
# Initiating batch 301 coroutine at 0.007289132000096288s after start
# Initiating batch 302 coroutine at 0.007300856000256317s after start
# Initiating batch 303 coroutine at 0.007312617000025057s after start
# Initiating batch 304 coroutine at 0.007324226000037015s after start
# Initiating batch 305 coroutine at 0.007335853000313364s after start
# Initiating batch 306 coroutine at 0.0073475120002512995s after start
# Initiating batch 307 coroutine at 0.007359583999914321s after start
# Initiating batch 308 coroutine at 0.007371227000021463s after start
# Initiating batch 309 coroutine at 0.007383895000202756s after start
# Initiating batch 310 coroutine at 0.007400741000310518s after start
# Initiating batch 311 coroutine at 0.007416082999952778s after start
# Initiating batch 312 coroutine at 0.00742796000031376s after start
# Initiating batch 313 coroutine at 0.0074395720002939925s after start
# Initiating batch 314 coroutine at 0.007451168999978108s after start
# Initiating batch 315 coroutine at 0.007462820999990072s after start
# Initiating batch 316 coroutine at 0.007474497000202973s after start
# Initiating batch 317 coroutine at 0.007485998999982257s after start
# Initiating batch 318 coroutine at 0.007497617999888462s after start
# Initiating batch 319 coroutine at 0.00750941900014368s after start
# Initiating batch 320 coroutine at 0.007521408000229712s after start
# Initiating batch 321 coroutine at 0.007533120000061899s after start
# Initiating batch 322 coroutine at 0.007545107000169082s after start
# Initiating batch 323 coroutine at 0.007556759000181046s after start
# Initiating batch 324 coroutine at 0.007568280000214145s after start
# Initiating batch 325 coroutine at 0.007579851000173221s after start
# Initiating batch 326 coroutine at 0.007591469000090001s after start
# Initiating batch 327 coroutine at 0.00760308899998563s after start
# Initiating batch 328 coroutine at 0.007614770000145654s after start
# Initiating batch 329 coroutine at 0.007626365000305668s after start
# Initiating batch 330 coroutine at 0.007637942000201292s after start
# Initiating batch 331 coroutine at 0.007649672000297869s after start
# Initiating batch 332 coroutine at 0.0076612749999185326s after start
# Initiating batch 333 coroutine at 0.007672946000184311s after start
# Initiating batch 334 coroutine at 0.007684444000005897s after start
# Initiating batch 335 coroutine at 0.007696201000271685s after start
# Initiating batch 336 coroutine at 0.007707733000188455s after start
# Initiating batch 337 coroutine at 0.007719291000285011s after start
# Initiating batch 338 coroutine at 0.007730922000064311s after start
# Initiating batch 339 coroutine at 0.0077425180002137495s after start
# Initiating batch 340 coroutine at 0.007755652000014379s after start
# Initiating batch 341 coroutine at 0.007767326000248431s after start
# Initiating batch 342 coroutine at 0.007778851000239229s after start
# Initiating batch 343 coroutine at 0.007790364999891608s after start
# Initiating batch 344 coroutine at 0.007809063999957289s after start
# Initiating batch 345 coroutine at 0.007820853999874089s after start
# Initiating batch 346 coroutine at 0.007832509000309074s after start
# Initiating batch 347 coroutine at 0.00784477200022593s after start
# Initiating batch 348 coroutine at 0.007856508000259055s after start
# Initiating batch 349 coroutine at 0.007868214000154694s after start
# Initiating batch 350 coroutine at 0.007879802999923413s after start
# Initiating batch 351 coroutine at 0.0078915640001469s after start
# Initiating batch 352 coroutine at 0.007903345000158879s after start
# Initiating batch 353 coroutine at 0.007914932999938173s after start
# Initiating batch 354 coroutine at 0.007926778000182821s after start
# Initiating batch 355 coroutine at 0.007939424000142026s after start
# Initiating batch 356 coroutine at 0.007951148000302055s after start
# Initiating batch 357 coroutine at 0.007962762000261137s after start
# Initiating batch 358 coroutine at 0.007974423000177921s after start
# Initiating batch 359 coroutine at 0.007985962000020663s after start
# Initiating batch 360 coroutine at 0.007997615000022051s after start
# Initiating batch 361 coroutine at 0.0080256270002792s after start
# Initiating batch 362 coroutine at 0.008038202000079764s after start
# Initiating batch 363 coroutine at 0.010448873000314052s after start
# Initiating batch 364 coroutine at 0.010511162000057084s after start
# Initiating batch 365 coroutine at 0.010533508000207803s after start
# Initiating batch 366 coroutine at 0.010549642000114545s after start
# Initiating batch 367 coroutine at 0.010568091000095592s after start
# Initiating batch 368 coroutine at 0.01058069800001249s after start
# Initiating batch 369 coroutine at 0.010594308000236197s after start
# Initiating batch 370 coroutine at 0.01063737399999809s after start
# Initiating batch 371 coroutine at 0.010653380999883666s after start
# Initiating batch 372 coroutine at 0.010665365000022575s after start
# Initiating batch 373 coroutine at 0.010677599000246119s after start
# Initiating batch 374 coroutine at 0.010689604000162944s after start
# Initiating batch 375 coroutine at 0.010701432000132627s after start
# Initiating batch 376 coroutine at 0.01071351600012349s after start
# Initiating batch 377 coroutine at 0.01072562299987112s after start
# Initiating batch 378 coroutine at 0.010737469000105193s after start
# Initiating batch 379 coroutine at 0.010749250000117172s after start
# Initiating batch 380 coroutine at 0.010760942000160867s after start
# Initiating batch 381 coroutine at 0.010772692000045936s after start
# Initiating batch 382 coroutine at 0.01078441500021654s after start
# Initiating batch 383 coroutine at 0.010796012999890081s after start
# Initiating batch 384 coroutine at 0.010808136999912676s after start
# Initiating batch 385 coroutine at 0.01082005600028424s after start
# Initiating batch 386 coroutine at 0.010834624999915832s after start
# Initiating batch 387 coroutine at 0.01084644999991724s after start
# Initiating batch 388 coroutine at 0.01085817200009842s after start
# Initiating batch 389 coroutine at 0.010869898000237299s after start
# Initiating batch 390 coroutine at 0.010881568000058905s after start
# Initiating batch 391 coroutine at 0.010893173000113165s after start
# Initiating batch 392 coroutine at 0.0109048909998819s after start
# Initiating batch 393 coroutine at 0.01091664400018999s after start
# Initiating batch 394 coroutine at 0.010928303000127926s after start
# Initiating batch 395 coroutine at 0.010940002000097593s after start
# Initiating batch 396 coroutine at 0.01095212000018364s after start
# Initiating batch 397 coroutine at 0.010963726000227325s after start
# Initiating batch 398 coroutine at 0.010975189999953727s after start
# Initiating batch 399 coroutine at 0.010986852000314684s after start
# Initiating batch 400 coroutine at 0.010998340000242024s after start
# Initiating batch 401 coroutine at 0.011009972000010748s after start
# Initiating batch 402 coroutine at 0.011027688000012859s after start
# Initiating batch 403 coroutine at 0.011039467000045988s after start
# Initiating batch 404 coroutine at 0.011051332000079128s after start
# Initiating batch 405 coroutine at 0.011062979000143969s after start
# Initiating batch 406 coroutine at 0.011075660000187781s after start
# Initiating batch 407 coroutine at 0.011087635999956547s after start
# Initiating batch 408 coroutine at 0.01109937399996852s after start
# Initiating batch 409 coroutine at 0.011110996000297746s after start
# Initiating batch 410 coroutine at 0.01112265900019338s after start
# Initiating batch 411 coroutine at 0.011134244999993825s after start
# Initiating batch 412 coroutine at 0.011146610000196233s after start
# Initiating batch 413 coroutine at 0.011158387000250514s after start
# Initiating batch 414 coroutine at 0.011170131000199035s after start
# Initiating batch 415 coroutine at 0.011181727999883151s after start
# Initiating batch 416 coroutine at 0.011193577000085497s after start
# Initiating batch 417 coroutine at 0.011205305000203225s after start
# Initiating batch 418 coroutine at 0.011244470000292495s after start
# Initiating batch 419 coroutine at 0.01126503000023149s after start
# Initiating batch 420 coroutine at 0.01128121400006421s after start
# Initiating batch 421 coroutine at 0.011298212999918178s after start
# Initiating batch 422 coroutine at 0.011315180000110558s after start
# Initiating batch 423 coroutine at 0.011328392999985226s after start
# Initiating batch 424 coroutine at 0.01134294100029365s after start
# Initiating batch 425 coroutine at 0.01136964400029683s after start
# Initiating batch 426 coroutine at 0.011386235999907512s after start
# Initiating batch 427 coroutine at 0.011398476000067603s after start
# Initiating batch 428 coroutine at 0.011410493000312272s after start
# Initiating batch 429 coroutine at 0.011422548000155075s after start
# Initiating batch 430 coroutine at 0.011436150999998063s after start
# Initiating batch 431 coroutine at 0.01145319199986261s after start
# Initiating batch 432 coroutine at 0.011469212000065454s after start
# Initiating batch 433 coroutine at 0.011484527999982674s after start
# Initiating batch 434 coroutine at 0.011497683000015968s after start
# Initiating batch 435 coroutine at 0.011644338000223797s after start
# Initiating batch 436 coroutine at 0.011656866000066657s after start
# Initiating batch 437 coroutine at 0.011668682000163244s after start
# Initiating batch 438 coroutine at 0.011683099000038055s after start
# Initiating batch 439 coroutine at 0.011694985000303859s after start
# Initiating batch 440 coroutine at 0.011707006000051479s after start
# Initiating batch 441 coroutine at 0.011718851000296127s after start
# Initiating batch 442 coroutine at 0.011730686000191781s after start
# Initiating batch 443 coroutine at 0.011742609000066295s after start
# Initiating batch 444 coroutine at 0.011754466000184038s after start
# Initiating batch 445 coroutine at 0.011766173000069102s after start
# Initiating batch 446 coroutine at 0.011784810999870388s after start
# Initiating batch 447 coroutine at 0.01179687300009391s after start
# Initiating batch 448 coroutine at 0.011808528000074148s after start
# Initiating batch 449 coroutine at 0.011820342000191886s after start
# Initiating batch 450 coroutine at 0.011832447999950091s after start
# Initiating batch 451 coroutine at 0.011844194999866886s after start
# Initiating batch 452 coroutine at 0.011855978000312462s after start
# Initiating batch 453 coroutine at 0.011867594000250392s after start
# Initiating batch 454 coroutine at 0.011879256000156602s after start
# Initiating batch 455 coroutine at 0.011894985000253655s after start
# Initiating batch 456 coroutine at 0.011907335000159947s after start
# Initiating batch 457 coroutine at 0.011919436999960453s after start
# Initiating batch 458 coroutine at 0.01193170500027918s after start
# Initiating batch 459 coroutine at 0.01194356499991045s after start
# Initiating batch 460 coroutine at 0.011955170999954134s after start
# Initiating batch 461 coroutine at 0.011966908999966108s after start
# Initiating batch 462 coroutine at 0.011978607999935775s after start
# Initiating batch 463 coroutine at 0.011991439000212267s after start
# Initiating batch 464 coroutine at 0.012003622000065661s after start
# Initiating batch 465 coroutine at 0.012015481000162254s after start
# Initiating batch 466 coroutine at 0.012027227000089624s after start
# Initiating batch 467 coroutine at 0.012038894999932381s after start
# Initiating batch 468 coroutine at 0.0120507510000607s after start
# Initiating batch 469 coroutine at 0.012062425000294752s after start
# Initiating batch 470 coroutine at 0.012074002000190376s after start
# Initiating batch 471 coroutine at 0.012087883000276634s after start
# Initiating batch 472 coroutine at 0.01210400199988726s after start
# Initiating batch 473 coroutine at 0.012119154000174603s after start
# Initiating batch 474 coroutine at 0.012131787000271288s after start
# Initiating batch 475 coroutine at 0.012143610000293847s after start
# Initiating batch 476 coroutine at 0.012155435000295256s after start
# Initiating batch 477 coroutine at 0.012167231000148604s after start
# Initiating batch 478 coroutine at 0.01218079399995986s after start
# Initiating batch 479 coroutine at 0.012196761000268452s after start
# Initiating batch 480 coroutine at 0.012212348000048223s after start
# Initiating batch 481 coroutine at 0.012230825000187906s after start
# Initiating batch 482 coroutine at 0.012242755999977817s after start
# Initiating batch 483 coroutine at 0.012254840999958105s after start
# Initiating batch 484 coroutine at 0.012267867999980808s after start
# Initiating batch 485 coroutine at 0.012284429999908753s after start
# Initiating batch 486 coroutine at 0.012300370000048133s after start
# Initiating batch 487 coroutine at 0.012315709000176867s after start
# Initiating batch 488 coroutine at 0.012327809999987949s after start
# Initiating batch 489 coroutine at 0.012339752000116277s after start
# Initiating batch 490 coroutine at 0.01235180699995908s after start
# Initiating batch 491 coroutine at 0.012366782000299281s after start
# Initiating batch 492 coroutine at 0.012382956000237755s after start
# Initiating batch 493 coroutine at 0.01239823100013382s after start
# Initiating batch 494 coroutine at 0.01241345700009333s after start
# Initiating batch 495 coroutine at 0.012428297000042221s after start
# Initiating batch 496 coroutine at 0.012442532000022766s after start
# Initiating batch 497 coroutine at 0.012459296000088216s after start
# Initiating batch 498 coroutine at 0.01247529400006897s after start
# Initiating batch 499 coroutine at 0.012490576999880432s after start
# Start sleep for batch 0, sleeping 0s, 0.017699874000300042s after start
# Start sleep for batch 1, sleeping 1.5s, 0.017752834000020812s after start
# Start sleep for batch 2, sleeping 3.0s, 0.01779438499988828s after start
# Start sleep for batch 3, sleeping 4.5s, 0.017831959999966784s after start
# Start sleep for batch 4, sleeping 6.0s, 0.01785878300006516s after start
# Start sleep for batch 5, sleeping 7.5s, 0.017883936000089307s after start
# Start sleep for batch 6, sleeping 9.0s, 0.017909665999923163s after start
# Start sleep for batch 7, sleeping 10.5s, 0.017934703000264562s after start
# Start sleep for batch 8, sleeping 12.0s, 0.017960979000235966s after start
# Start sleep for batch 9, sleeping 13.5s, 0.017986304000260134s after start
# Start sleep for batch 10, sleeping 15.0s, 0.01801238000007288s after start
# Start sleep for batch 11, sleeping 16.5s, 0.018037609000202792s after start
# Start sleep for batch 12, sleeping 18.0s, 0.018063090999930864s after start
# Start sleep for batch 13, sleeping 19.5s, 0.018088462999912736s after start
# Start sleep for batch 14, sleeping 21.0s, 0.01811331099997915s after start
# Start sleep for batch 15, sleeping 22.5s, 0.018138372000066738s after start
# Start sleep for batch 16, sleeping 24.0s, 0.018163661000016873s after start
# Start sleep for batch 17, sleeping 25.5s, 0.018188540000210196s after start
# Start sleep for batch 18, sleeping 27.0s, 0.01821381800027666s after start
# Start sleep for batch 19, sleeping 28.5s, 0.018238338000173826s after start
# Start sleep for batch 20, sleeping 30.0s, 0.0182638119999865s after start
# Start sleep for batch 21, sleeping 31.5s, 0.018289205000201036s after start
# Start sleep for batch 22, sleeping 33.0s, 0.018329404000269278s after start
# Start sleep for batch 23, sleeping 34.5s, 0.01835507600026176s after start
# Start sleep for batch 24, sleeping 36.0s, 0.01838086999987354s after start
# Start sleep for batch 25, sleeping 37.5s, 0.018405380999865883s after start
# Start sleep for batch 26, sleeping 39.0s, 0.01843082899995352s after start
# Start sleep for batch 27, sleeping 40.5s, 0.018456455999967147s after start
# Start sleep for batch 28, sleeping 42.0s, 0.018481644000075903s after start
# Start sleep for batch 29, sleeping 43.5s, 0.01850633200001539s after start
# Start sleep for batch 30, sleeping 45.0s, 0.018531775000155903s after start
# Start sleep for batch 31, sleeping 46.5s, 0.018557500000042637s after start
# Start sleep for batch 32, sleeping 48.0s, 0.018582797999897593s after start
# Start sleep for batch 33, sleeping 49.5s, 0.018632324999998673s after start
# Start sleep for batch 34, sleeping 51.0s, 0.018667381999875943s after start
# Start sleep for batch 35, sleeping 52.5s, 0.018694959000185918s after start
# Start sleep for batch 36, sleeping 54.0s, 0.01872048699988227s after start
# Start sleep for batch 37, sleeping 55.5s, 0.018746257000202604s after start
# Start sleep for batch 38, sleeping 57.0s, 0.018778905000090163s after start
# Start sleep for batch 39, sleeping 58.5s, 0.018810591000146815s after start
# Start sleep for batch 40, sleeping 60.0s, 0.01884186999996018s after start
# Start sleep for batch 41, sleeping 61.5s, 0.01886748400011129s after start
# Start sleep for batch 42, sleeping 63.0s, 0.018892676000177744s after start
# Start sleep for batch 43, sleeping 64.5s, 0.01891771200007497s after start
# Start sleep for batch 44, sleeping 66.0s, 0.01894347600000401s after start
# Start sleep for batch 45, sleeping 67.5s, 0.01896889399995416s after start
# Start sleep for batch 46, sleeping 69.0s, 0.01899365100007344s after start
# Start sleep for batch 47, sleeping 70.5s, 0.019018156000129238s after start
# Start sleep for batch 48, sleeping 72.0s, 0.01904475800029104s after start
# Start sleep for batch 49, sleeping 73.5s, 0.019070232000103715s after start
# Start sleep for batch 50, sleeping 75.0s, 0.019096410000202013s after start
# Start sleep for batch 51, sleeping 76.5s, 0.019121495000035793s after start
# Start sleep for batch 52, sleeping 78.0s, 0.01914721399998598s after start
# Start sleep for batch 53, sleeping 79.5s, 0.01917258599996785s after start
# Start sleep for batch 54, sleeping 81.0s, 0.019197476000044844s after start
# Start sleep for batch 55, sleeping 82.5s, 0.01922271000012188s after start
# Start sleep for batch 56, sleeping 84.0s, 0.019248439999955735s after start
# Start sleep for batch 57, sleeping 85.5s, 0.01927403800027605s after start
# Start sleep for batch 58, sleeping 87.0s, 0.019305175000226882s after start
# Start sleep for batch 59, sleeping 88.5s, 0.019331235000208835s after start
# Start sleep for batch 60, sleeping 90.0s, 0.019357433000095625s after start
# Start sleep for batch 61, sleeping 91.5s, 0.01938590600002499s after start
# Start sleep for batch 62, sleeping 93.0s, 0.019410795000112557s after start
# Start sleep for batch 63, sleeping 94.5s, 0.019435896000231878s after start
# Start sleep for batch 64, sleeping 96.0s, 0.019461188000150287s after start
# Start sleep for batch 65, sleeping 97.5s, 0.019486504000269633s after start
# Start sleep for batch 66, sleeping 99.0s, 0.019512631999987207s after start
# Start sleep for batch 67, sleeping 100.5s, 0.01953736099994785s after start
# Start sleep for batch 68, sleeping 102.0s, 0.01956341599998268s after start
# Start sleep for batch 69, sleeping 103.5s, 0.019589150000228983s after start
# Start sleep for batch 70, sleeping 105.0s, 0.019615453999904275s after start
# Start sleep for batch 71, sleeping 106.5s, 0.019645623000087653s after start
# Start sleep for batch 72, sleeping 108.0s, 0.019676483000239386s after start
# Start sleep for batch 73, sleeping 109.5s, 0.019702471000073274s after start
# Start sleep for batch 74, sleeping 111.0s, 0.01973569400024644s after start
# Start sleep for batch 75, sleeping 112.5s, 0.019769062000250415s after start
# Start sleep for batch 76, sleeping 114.0s, 0.01979771400010577s after start
# Start sleep for batch 77, sleeping 115.5s, 0.019823751999865635s after start
# Start sleep for batch 78, sleeping 117.0s, 0.019850953000059235s after start
# Start sleep for batch 79, sleeping 118.5s, 0.019876457000009395s after start
# Start sleep for batch 80, sleeping 120.0s, 0.019903155000065453s after start
# Start sleep for batch 81, sleeping 121.5s, 0.019929531999878236s after start
# Start sleep for batch 82, sleeping 123.0s, 0.01995534800016685s after start
# Start sleep for batch 83, sleeping 124.5s, 0.019980732000021817s after start
# Start sleep for batch 84, sleeping 126.0s, 0.020006363999982568s after start
# Start sleep for batch 85, sleeping 127.5s, 0.020032395000271208s after start
# Start sleep for batch 86, sleeping 129.0s, 0.020058321000306023s after start
# Start sleep for batch 87, sleeping 130.5s, 0.02008369200029847s after start
# Start sleep for batch 88, sleeping 132.0s, 0.020109157000206324s after start
# Start sleep for batch 89, sleeping 133.5s, 0.020134298999892053s after start
# Start sleep for batch 90, sleeping 135.0s, 0.020161331000053906s after start
# Start sleep for batch 91, sleeping 136.5s, 0.020186705000014626s after start
# Start sleep for batch 92, sleeping 138.0s, 0.020211996999933035s after start
# Start sleep for batch 93, sleeping 139.5s, 0.02023726400011583s after start
# Start sleep for batch 94, sleeping 141.0s, 0.02026258300020345s after start
# Start sleep for batch 95, sleeping 142.5s, 0.02028757600010067s after start
# Start sleep for batch 96, sleeping 144.0s, 0.020325115000105143s after start
# Start sleep for batch 97, sleeping 145.5s, 0.020356023000204004s after start
# Start sleep for batch 98, sleeping 147.0s, 0.02038932899995416s after start
# Start sleep for batch 99, sleeping 148.5s, 0.020418340000105673s after start
# Start sleep for batch 100, sleeping 150.0s, 0.02044421800019336s after start
# Start sleep for batch 101, sleeping 151.5s, 0.020470031000058952s after start
# Start sleep for batch 102, sleeping 153.0s, 0.020495348000167724s after start
# Start sleep for batch 103, sleeping 154.5s, 0.02052062200027649s after start
# Start sleep for batch 104, sleeping 156.0s, 0.02054556000030061s after start
# Start sleep for batch 105, sleeping 157.5s, 0.02057165199994415s after start
# Start sleep for batch 106, sleeping 159.0s, 0.020604113999979745s after start
# Start sleep for batch 107, sleeping 160.5s, 0.020636394000121072s after start
# Start sleep for batch 108, sleeping 162.0s, 0.02066695100029392s after start
# Start sleep for batch 109, sleeping 163.5s, 0.020692240000244055s after start
# Start sleep for batch 110, sleeping 165.0s, 0.02071782400025768s after start
# Start sleep for batch 111, sleeping 166.5s, 0.020742522000091412s after start
# Start sleep for batch 112, sleeping 168.0s, 0.020767580000210728s after start
# Start sleep for batch 113, sleeping 169.5s, 0.02079283100010798s after start
# Start sleep for batch 114, sleeping 171.0s, 0.02081795799995234s after start
# Start sleep for batch 115, sleeping 172.5s, 0.020842776999870694s after start
# Start sleep for batch 116, sleeping 174.0s, 0.020868613999937224s after start
# Start sleep for batch 117, sleeping 175.5s, 0.020893974000046s after start
# Start sleep for batch 118, sleeping 177.0s, 0.020918610000080662s after start
# Start sleep for batch 119, sleeping 178.5s, 0.02094367500012595s after start
# Start sleep for batch 120, sleeping 180.0s, 0.020969423000224197s after start
# Start sleep for batch 121, sleeping 181.5s, 0.020995371000026353s after start
# Start sleep for batch 122, sleeping 183.0s, 0.021021747000304458s after start
# Start sleep for batch 123, sleeping 184.5s, 0.02104729100028635s after start
# Start sleep for batch 124, sleeping 186.0s, 0.021072371000173007s after start
# Start sleep for batch 125, sleeping 187.5s, 0.02109783600008086s after start
# Start sleep for batch 126, sleeping 189.0s, 0.021123072000136744s after start
# Start sleep for batch 127, sleeping 190.5s, 0.02114877800022441s after start
# Start sleep for batch 128, sleeping 192.0s, 0.021175215000312164s after start
# Start sleep for batch 129, sleeping 193.5s, 0.02120122199994512s after start
# Start sleep for batch 130, sleeping 195.0s, 0.021226076999937504s after start
# Start sleep for batch 131, sleeping 196.5s, 0.02125178699998287s after start
# Start sleep for batch 132, sleeping 198.0s, 0.021277308000207995s after start
# Start sleep for batch 133, sleeping 199.5s, 0.02130967299990516s after start
# Start sleep for batch 134, sleeping 201.0s, 0.021335148000162008s after start
# Start sleep for batch 135, sleeping 202.5s, 0.021360261000154424s after start
# Start sleep for batch 136, sleeping 204.0s, 0.02138603499997771s after start
# Start sleep for batch 137, sleeping 205.5s, 0.021410130000276695s after start
# Start sleep for batch 138, sleeping 207.0s, 0.021435499000290292s after start
# Start sleep for batch 139, sleeping 208.5s, 0.021459716000208573s after start
# Start sleep for batch 140, sleeping 210.0s, 0.02148498499991547s after start
# Start sleep for batch 141, sleeping 211.5s, 0.021509691000119346s after start
# Start sleep for batch 142, sleeping 213.0s, 0.021534923000217532s after start
# Start sleep for batch 143, sleeping 214.5s, 0.0215598120003051s after start
# Start sleep for batch 144, sleeping 216.0s, 0.02158460600003309s after start
# Start sleep for batch 145, sleeping 217.5s, 0.02160882299995137s after start
# Start sleep for batch 146, sleeping 219.0s, 0.021633696000208147s after start
# Start sleep for batch 147, sleeping 220.5s, 0.02165858800026399s after start
# Start sleep for batch 148, sleeping 222.0s, 0.02168399700030932s after start
# Start sleep for batch 149, sleeping 223.5s, 0.02170815899989975s after start
# Start sleep for batch 150, sleeping 225.0s, 0.02173359700009314s after start
# Start sleep for batch 151, sleeping 226.5s, 0.0217578050001066s after start
# Start sleep for batch 152, sleeping 228.0s, 0.021782081000310427s after start
# Start sleep for batch 153, sleeping 229.5s, 0.021806189000017184s after start
# Start sleep for batch 154, sleeping 231.0s, 0.02183035200005179s after start
# Start sleep for batch 155, sleeping 232.5s, 0.021855272000266268s after start
# Start sleep for batch 156, sleeping 234.0s, 0.02187987300021632s after start
# Start sleep for batch 157, sleeping 235.5s, 0.022076650000144582s after start
# Start sleep for batch 158, sleeping 237.0s, 0.022103904000232433s after start
# Start sleep for batch 159, sleeping 238.5s, 0.02212833600015074s after start
# Start sleep for batch 160, sleeping 240.0s, 0.022153086999878724s after start
# Start sleep for batch 161, sleeping 241.5s, 0.022178788000019267s after start
# Start sleep for batch 162, sleeping 243.0s, 0.022203907999937655s after start
# Start sleep for batch 163, sleeping 244.5s, 0.02222900100014158s after start
# Start sleep for batch 164, sleeping 246.0s, 0.022254009999869595s after start
# Start sleep for batch 165, sleeping 247.5s, 0.02227904200026387s after start
# Start sleep for batch 166, sleeping 249.0s, 0.022308716000225104s after start
# Start sleep for batch 167, sleeping 250.5s, 0.022333386999889626s after start
# Start sleep for batch 168, sleeping 252.0s, 0.022358431000156997s after start
# Start sleep for batch 169, sleeping 253.5s, 0.022382863000075304s after start
# Start sleep for batch 170, sleeping 255.0s, 0.022407321000173397s after start
# Start sleep for batch 171, sleeping 256.5s, 0.022432725000271603s after start
# Start sleep for batch 172, sleeping 258.0s, 0.022457739999936166s after start
# Start sleep for batch 173, sleeping 259.5s, 0.02248326700009784s after start
# Start sleep for batch 174, sleeping 261.0s, 0.022509249999984604s after start
# Start sleep for batch 175, sleeping 262.5s, 0.022535078000146314s after start
# Start sleep for batch 176, sleeping 264.0s, 0.02255997500014928s after start
# Start sleep for batch 177, sleeping 265.5s, 0.022584317000109877s after start
# Start sleep for batch 178, sleeping 267.0s, 0.022632222000083857s after start
# Start sleep for batch 179, sleeping 268.5s, 0.02265824899996005s after start
# Start sleep for batch 180, sleeping 270.0s, 0.022683591000259185s after start
# Start sleep for batch 181, sleeping 271.5s, 0.02270847199997661s after start
# ...
# Batch 377 complete after 1.2643517559999964s
# Starting batch 378 at 567.0291479890002s after start
# Batch 378 complete after 1.0602772229999573s
# Starting batch 379 at 568.529691831s after start
# Batch 379 complete after 1.0414240699997208s
# Starting batch 380 at 570.0291900070001s after start
# Batch 380 complete after 1.264982965999934s
# Starting batch 381 at 571.528929477s after start
# Batch 381 complete after 1.1991110339999977s
# Starting batch 382 at 573.0288666740003s after start
# Batch 382 complete after 1.2061409119996824s
# Starting batch 383 at 574.528792131s after start
# Batch 383 complete after 1.0815510060001543s
# Starting batch 384 at 576.0292298230002s after start
# Batch 384 complete after 1.2353204619998905s
# Starting batch 385 at 577.529326031s after start
# Batch 385 complete after 1.0885999209999682s
# Starting batch 386 at 579.0308404699999s after start
# Batch 386 complete after 1.107041866000145s
# Starting batch 387 at 580.5297258139999s after start
# Batch 387 complete after 1.3134392860001753s
# Starting batch 388 at 582.0288474150002s after start
# Batch 388 complete after 1.1379962780001733s
# Starting batch 389 at 583.5295909060001s after start
# Batch 389 complete after 1.2021892630000366s
# Starting batch 390 at 585.0295807410002s after start
# Batch 390 complete after 1.0529331870002352s
# Starting batch 391 at 586.5294903050003s after start
# Batch 391 complete after 1.1880119180000293s
# Starting batch 392 at 588.029295846s after start
# Batch 392 complete after 1.0470985470001324s
# Starting batch 393 at 589.5293742839999s after start
# Batch 393 complete after 1.07602066499976s
# Starting batch 394 at 591.0293400360001s after start
# Batch 394 complete after 1.17975085199987s
# Starting batch 395 at 592.5298808930002s after start
# Batch 395 complete after 1.1810375420000128s
# Starting batch 396 at 594.0297217050002s after start
# Batch 396 complete after 1.2672539990003315s
# Starting batch 397 at 595.5296966820001s after start
# Batch 397 complete after 1.0642995030002567s
# Starting batch 398 at 597.029959255s after start
# Batch 398 complete after 1.1158241060002183s
# Starting batch 399 at 598.5296289480002s after start
# Batch 399 complete after 1.2021691900004043s
# Starting batch 400 at 600.0295936370003s after start
# Batch 400 complete after 1.0541542500000105s
# Starting batch 401 at 601.5296613569999s after start
# Batch 401 complete after 1.2550218849996782s
# Starting batch 402 at 603.0294466730002s after start
# Batch 402 complete after 1.1818517390001944s
# Starting batch 403 at 604.5300929559999s after start
# Batch 403 complete after 1.076027389999581s
# Starting batch 404 at 606.0303789210002s after start
# Batch 404 complete after 1.0988803949999237s
# Starting batch 405 at 607.5301939179999s after start
# Batch 405 complete after 1.2365722580002512s
# Starting batch 406 at 609.0297670979999s after start
# Batch 406 complete after 1.3451284330003546s
# Starting batch 407 at 610.529554231s after start
# Batch 407 complete after 1.1488571599998068s
# Starting batch 408 at 612.0312039370001s after start
# Batch 408 complete after 1.1999323200002436s
# Starting batch 409 at 613.529948717s after start
# Batch 409 complete after 1.26313594200019s
# Starting batch 410 at 615.0308177730003s after start
# Batch 410 complete after 1.2764386640001248s
# Starting batch 411 at 616.5299404390003s after start
# Batch 411 complete after 1.0830346940001618s
# Starting batch 412 at 618.0308883000002s after start
# Batch 412 complete after 1.193019065000044s
# Starting batch 413 at 619.5297155210001s after start
# Batch 413 complete after 1.1208985859998393s
# Starting batch 414 at 621.0297428140002s after start
# Batch 414 complete after 1.142049224999937s
# Starting batch 415 at 622.5297754220001s after start
# Batch 415 complete after 1.1905418320002354s
# Starting batch 416 at 624.0301590720001s after start
# Batch 416 complete after 1.1594188990002294s
# Starting batch 417 at 625.5304363939999s after start
# Batch 417 complete after 1.2200022540000646s
# Starting batch 418 at 627.0302668869999s after start
# Batch 418 complete after 1.1857060140000613s
# Starting batch 419 at 628.5297614410001s after start
# Batch 419 complete after 1.066264001000036s
# Starting batch 420 at 630.0299870019999s after start
# Batch 420 complete after 1.2508597750002082s
# Starting batch 421 at 631.530580225s after start
# Batch 421 complete after 0.9960895189997245s
# Starting batch 422 at 633.0299978799999s after start
# Batch 422 complete after 1.1354496910003036s
# Starting batch 423 at 634.530314223s after start
# Batch 423 complete after 1.2143466449997504s
# Starting batch 424 at 636.031499141s after start
# Batch 424 complete after 1.0975521020000087s
# Starting batch 425 at 637.5299376920002s after start
# Batch 425 complete after 1.2612499329998172s
# Starting batch 426 at 639.0312101520003s after start
# Batch 426 complete after 1.005352541999855s
# Starting batch 427 at 640.5305132160001s after start
# Batch 427 complete after 1.1689035100002911s
# Starting batch 428 at 642.0302692270002s after start
# Batch 428 complete after 1.2068351010002516s
# Starting batch 429 at 643.5299606640001s after start
# Batch 429 complete after 1.13464822800006s
# Starting batch 430 at 645.0304989250003s after start
# Batch 430 complete after 1.14152540699979s
# Starting batch 431 at 646.530273074s after start
# Batch 431 complete after 1.1256944710003154s
# Starting batch 432 at 648.0308186319999s after start
# Batch 432 complete after 1.1922137830001702s
# Starting batch 433 at 649.5301074960003s after start
# Batch 433 complete after 1.042936701999679s
# Starting batch 434 at 651.0309600680002s after start
# Batch 434 complete after 1.135615173000133s
# Starting batch 435 at 652.5303640330003s after start
# Batch 435 complete after 1.073112818000027s
# Starting batch 436 at 654.0304156309999s after start
# Batch 436 complete after 1.1418258859998787s
# Starting batch 437 at 655.530267478s after start
# Batch 437 complete after 1.3006741670001247s
# Starting batch 438 at 657.0302713670003s after start
# Batch 438 complete after 1.2509270529999412s
# Starting batch 439 at 658.5308969749999s after start
# Batch 439 complete after 1.196831600999758s
# Starting batch 440 at 660.0306310680003s after start
# Batch 440 complete after 1.301858940999864s
# Starting batch 441 at 661.5301811140002s after start
# Batch 441 complete after 1.2285408999996434s
# Starting batch 442 at 663.0304033580001s after start
# Batch 442 complete after 1.0141820570001983s
# Starting batch 443 at 664.530722303s after start
# Batch 443 complete after 1.198585025000284s
# Starting batch 444 at 666.0303926199999s after start
# Batch 444 complete after 1.2293632219998472s
# Starting batch 445 at 667.5304988000003s after start
# Batch 445 complete after 1.1730959540000185s
# Starting batch 446 at 669.030492845s after start
# Batch 446 complete after 1.1007480309999664s
# Starting batch 447 at 670.530952442s after start
# Batch 447 complete after 1.2207954690002225s
# Starting batch 448 at 672.0308425789999s after start
# Batch 448 complete after 1.0373694059999252s
# Starting batch 449 at 673.531578781s after start
# Batch 449 complete after 1.1228306080001857s
# Starting batch 450 at 675.0313221040001s after start
# Batch 450 complete after 1.090248223999879s
# Starting batch 451 at 676.5324724470001s after start
# Batch 451 complete after 1.2695241870001155s
# Starting batch 452 at 678.031118678s after start
# Batch 452 complete after 1.0482780550000825s
# Starting batch 453 at 679.5313942100001s after start
# Batch 453 complete after 1.275538116000007s
# Starting batch 454 at 681.030694308s after start
# Batch 454 complete after 1.100166131000151s
# Starting batch 455 at 682.5311032089999s after start
# Batch 455 complete after 1.198329848999947s
# Starting batch 456 at 684.0332737200001s after start
# Batch 456 complete after 1.22798390700018s
# Starting batch 457 at 685.5330293810002s after start
# Batch 457 complete after 1.2170765290002237s
# Starting batch 458 at 687.032913131s after start
# Batch 458 complete after 1.0266733660000682s
# Starting batch 459 at 688.5345720630003s after start
# Batch 459 complete after 1.2794032130000232s
# Starting batch 460 at 690.032720355s after start
# Batch 460 complete after 1.2115740989997903s
# Starting batch 461 at 691.5340975690001s after start
# Batch 461 complete after 1.271382420000009s
# Starting batch 462 at 693.033197532s after start
# Batch 462 complete after 1.0533988160000263s
# Starting batch 463 at 694.5335240300001s after start
# Batch 463 complete after 1.3495308560000012s
# Starting batch 464 at 696.0330142540001s after start
# Batch 464 complete after 1.2183485529999416s
# Starting batch 465 at 697.5330436090003s after start
# Batch 465 complete after 1.0566493579999587s
# Starting batch 466 at 699.0338893140001s after start
# Batch 466 complete after 1.2266035190000366s
# Starting batch 467 at 700.533550095s after start
# Batch 467 complete after 1.1830240199997206s
# Starting batch 468 at 702.0335760140001s after start
# Batch 468 complete after 1.1634208129999024s
# Starting batch 469 at 703.5340430670003s after start
# Batch 469 complete after 1.2496409489999678s
# Starting batch 470 at 705.0336829339999s after start
# Batch 470 complete after 1.184238443999675s
# Starting batch 471 at 706.5337482760001s after start
# Batch 471 complete after 1.1712799759998234s
# Starting batch 472 at 708.0338915850002s after start
# Batch 472 complete after 1.1763576270000158s
# Starting batch 473 at 709.534089924s after start
# Batch 473 complete after 1.1881887800000186s
# Starting batch 474 at 711.0341175880003s after start
# Batch 474 complete after 1.136264790000041s
# Starting batch 475 at 712.533241609s after start
# Batch 475 complete after 0.9934459959999913s
# Starting batch 476 at 714.0336708620002s after start
# Batch 476 complete after 1.1729120019999755s
# Starting batch 477 at 715.5337054030001s after start
# Batch 477 complete after 1.2293529489998036s
# Starting batch 478 at 717.0338345099999s after start
# Batch 478 complete after 1.004434453000158s
# Starting batch 479 at 718.5342335750001s after start
# Batch 479 complete after 1.0283997919996182s
# Starting batch 480 at 720.0335957540001s after start
# Batch 480 complete after 0.9942035990002296s
# Starting batch 481 at 721.5340622809999s after start
# Batch 481 complete after 1.2792087059997357s
# Starting batch 482 at 723.0339957659999s after start
# Batch 482 complete after 0.9488296949998585s
# Starting batch 483 at 724.5338457309999s after start
# Batch 483 complete after 0.3280573160000131s
# Starting batch 484 at 726.034477578s after start
# Batch 484 complete after 1.2612307160002274s
# Starting batch 485 at 727.5347665230001s after start
# Batch 485 complete after 0.32337076900012107s
# Starting batch 486 at 729.0347416720001s after start
# Batch 486 complete after 1.2125213039998926s
# Starting batch 487 at 730.5350281450001s after start
# Batch 487 complete after 1.2170691750002334s
# Starting batch 488 at 732.0338294940002s after start
# Batch 488 complete after 0.9471336429996882s
# Starting batch 489 at 733.534327286s after start
# Batch 489 complete after 0.9542243050000252s
# Starting batch 490 at 735.0346265570001s after start
# Starting batch 491 at 736.5362889500002s after start
# Batch 490 complete after 1.7901364880003712s
# Batch 491 complete after 0.9421282869998322s
# Starting batch 492 at 738.0348238209999s after start
# Batch 492 complete after 1.2268373140000222s
# Starting batch 493 at 739.5344034280001s after start
# Batch 493 complete after 0.3229342310000902s
# Starting batch 494 at 741.0349357770001s after start
# Batch 494 complete after 1.2194115950001105s
# Starting batch 495 at 742.5340902170001s after start
# Batch 495 complete after 1.2362225749998288s
# Starting batch 496 at 744.0340373260001s after start
# Batch 496 complete after 0.33106447500040304s
# Starting batch 497 at 745.534745169s after start
# Batch 497 complete after 0.34109813400027633s
# Starting batch 498 at 747.035415371s after start
# Batch 498 complete after 0.3282694829999855s
# Starting batch 499 at 748.535229218s after start
# Batch 499 complete after 0.32442211099987617s
# 500 batches of 2 jobs each took 748.8601772709999s
# Response times [1.2143667230002393, 1.088154818000021, 1.1009585749998223, 1.2254270339999493, 1.142188513000292, 1.2883249720002823, 1.0421565579999879, 1.2450928500002192, 1.0549058500000683, 1.1058162089998405, 1.275659063999683, 1.077939695999703, 1.0423663090000446, 1.7986824469999192, 1.3347509569998692, 1.2052341720000186, 1.0332412689999728, 1.1702457300002607, 1.076744693999899, 0.9614407340000071, 1.324099839000155, 1.1028620070001125, 1.071145104000152, 1.7908626520002144, 1.2445561470003668, 1.1161027499997545, 1.0721067700001186, 0.999980492999839, 1.1157319479998478, 1.2399656839997988, 1.222091651000028, 1.0145355860004202, 1.1954659980001452, 1.2238680030000069, 1.1046829990000333, 1.1653048860002855, 1.1437359130000004, 1.0091429650001373, 1.2592086409999865, 1.066017157999795, 1.1324343749997752, 1.3226693659999, 1.0841002050001407, 1.0145402959997227, 1.144072149999829, 1.0871289179999621, 1.0802510989997245, 1.2517816049999055, 1.1803123840004446, 1.2758946760000072, 1.2083151899996665, 0.9774123059996782, 0.9714641000000483, 1.0870227049999812, 1.0431834289997823, 1.2236000520001653, 1.0696257909999076, 1.146511903999908, 1.069295491000048, 1.0896953859996756, 1.0814554380003756, 1.0740653379998548, 1.0242135259995848, 1.2114173949998985, 1.1387110649998249, 1.1741240520000247, 1.338433365000128, 1.034855403000165, 1.168676583999968, 1.1881191369998305, 1.174640205000287, 1.3172812789998716, 1.1778828460001023, 1.2180360390002534, 1.0261236850001296, 1.173914767000042, 1.2306815930000994, 1.0882992419997208, 1.0608521609997297, 1.1235662090002734, 1.1439624439999534, 1.0922639120003623, 1.062672542999735, 1.0154736709996541, 0.9726475080001364, 1.466682996000145, 1.0761899979997906, 1.1393704429997342, 1.1547596380000869, 1.2182876990000295, 1.0619278869999107, 1.0233639899997797, 1.0437862569997378, 1.076180092999948, 1.2327978520002034, 1.2648758340001223, 1.0072866489999797, 1.3118376030001855, 1.18804787199997, 1.0941180139998323, 1.0542359230003058, 1.1856851100001222, 1.0692423909999889, 1.052096808999977, 1.0687537630001316, 1.1897167659999468, 1.0135390160003226, 1.0109258880002017, 1.1306697360000726, 1.0560564960001102, 0.980017461999978, 1.2584758050002165, 1.2355933259996164, 1.2506112969999776, 1.0501370669999233, 1.1842586190000475, 1.3320481239998117, 0.9658319440000014, 1.3093569090001438, 1.208664792000036, 1.0866954680000163, 1.0496626670001206, 1.158983416999945, 1.0590708439999617, 1.043551430000207, 1.3484835059998659, 1.2584721100001843, 1.0329527509998115, 1.0744442320001326, 1.240123720000156, 1.0202784709999833, 0.9880655960000695, 1.1295561470001303, 1.054616851999981, 1.0552173339997353, 1.1908573250002519, 1.2878948180000407, 1.0593428470001527, 1.111566073999711, 1.01333915000032, 1.04103143500015, 1.0327137559997936, 1.0578382599996985, 1.3377186970001276, 1.251470018999953, 1.1960520100001304, 1.0284096250002221, 1.104070994000267, 1.1118987670001843, 1.243212799000048, 1.0217964239996036, 1.0652518169999894, 1.0634971530002986, 1.0648546840002382, 1.051080415999877, 1.274480148999828, 1.0741013920001024, 1.0775818840002103, 1.0760533659999965, 1.2687992609999128, 1.015260772000147, 1.229432984000141, 1.0857022529999085, 1.080408007999722, 1.0314041790002193, 1.03628185999969, 1.1344454899999619, 1.06890912200015, 1.0315314219997163, 1.0618716009998934, 1.26707083600013, 1.0674972309998338, 1.0637903390002066, 1.0285692099996595, 1.2488514589999795, 1.0518175980000706, 1.0863456970000698, 1.0449871509999866, 1.0718811990000177, 1.1673621909999383, 1.0682821579998745, 1.1095441059997029, 1.077040766999744, 1.0154404119998617, 1.2357255259998965, 1.161931081000148, 1.248156660999939, 1.0353710310000679, 1.13532325999995, 1.0382190549998995, 1.2772997629999736, 1.0121933240002363, 1.04897169700007, 1.0200819629999387, 1.251783101000001, 1.0228868280000825, 1.0487704780002787, 1.1044705710000926, 1.027875698999651, 1.032165698999961, 1.0593790509997234, 1.1665206130001025, 1.1599 ...
# Mean batch response time 1.1377849665680024

# %%
# STUFF FOR INTERARRIVAL BETWEEN JOBS NOT NEEDED

# job_response_times = []
# job_response_times = [0 for i in range(njobs)]

# interarrival times for jobs
# inter_arrival_times = []
# inter_arrival_times = [0 for i in range(njobs)]

# arrival_times = []
# arrival_times = [0 for i in range(njobs)]
# arrival_times[0]=round(inter_arrival_times[0],2)#arrival of first customer
# #Generate arrival times
# for i in range(1,njobs):
#     arrival_times[i]=round((arrival_times[i-1]+inter_arrival_times[i]),2)

# %%
# async def predict(session: aiohttp.ClientSession, instances: list, curCust: int, offset: int, start_time: float) -> dict:
    
#     # Simulating arrival times
#     # await asyncio.sleep(arrival_times[curCust])

#     image = file_string[curCust+offset]
#     # print("{} started {}s after start".format(image, time.monotonic() - start_time))
    
#     job_sent_time = time.monotonic()
#     headers = {"Authorization": "Bearer {}".format(auth_token)}
#     payload = {"instances" : instances[curCust:(curCust+1)]}
#     resp = await session.post(url, json=payload, headers=headers)
#     job_response_times[curCust] = time.monotonic() - job_sent_time
    
#     data = await resp.json()
    
#     # print("{} finished in {}s".format(file_string[curCust+offset],job_response_times[curCust]))
#     # return data # Uncomment to see if your reqest is working correctly
#     return image


# async def main(instances):
#     async with aiohttp.ClientSession() as session:
        
#         start_time = time.monotonic()
#         tasks = []
        
#         for c in range(0,njobs):
#             tasks.append(predict(session=session, instances=instances, curCust=c, offset=offset, start_time=start_time))
            
#         # asyncio.gather() will wait on the entire task set to be
#         # completed.  If you want to process results greedily as they come in,
#         # loop over asyncio.as_completed()
#         labels = await asyncio.gather(*tasks, return_exceptions=True)
#         total_time = time.monotonic() - start_time
        
#         print("{} predictions took {} seconds".format(njobs, total_time))
#         # print("Response times {}".format(job_response_times))
#         print("Mean response time {}".format(mean(job_response_times)))
        
#         return labels
        
# await main(instances)
